# %%
# %matplotlib ipympl
import numpy as np
import os 
import matplotlib.pyplot as plt
import re

# %%
## paths ##
directory = '/home/tomh/Documents/projects/czebra/archived_models/230920/f1_221103_spot-label_second-half-stims_time-since-last_tectal_10000rois_2000iters_128hidden_0.001L2_0.8train/script'
filename_list = ['v5_RMSE.txt', 'v4_predict-on-train_RMSE.txt']
filename = filename_list[1]
filepath = directory + os.sep + filename

# %%
## read in from file ##
with open(filepath, 'r') as f:
    contents = f.read()


pattern = re.compile('\d\d\d\.\d*')
values = re.findall(pattern, contents)

# convert to float
for i in range(len(values)):
    val = values[i]
    values[i] = float(val)

# convert to array
values = np.array(values)

# %%
## plot data ##

# create x values
x = np.arange(100,2001,100)

# plot
fig, ax = plt.subplots()
ax.plot(x, values)
plt.xlabel('Training iterations')
plt.ylabel('root MSE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/tomh/Documents/projects/czebra/figures/RMSE.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/home/tomh/Documents/projects/czebra/figures/RMSE.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> # plot
#       <a href='vscode-notebook-cell:/home/tomh/Documents/projects/czebra/figures/RMSE.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> fig, ax = plt.subplots()
# ----> <a href='vscode-notebook-cell:/home/tomh/Documents/projects/czebra/figures/RMSE.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> ax.plot(x, values)
#       <a href='vscode-notebook-cell:/home/tomh/Documents/projects/czebra/figures/RMSE.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> plt.xlabel('Training iterations')
#      <a href='vscode-notebook-cell:/home/tomh/Documents/projects/czebra/figures/RMSE.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> plt.ylabel('root MSE')
#
# ...

# %%
## plot data ##

#deconv 1e-06 predict-on-train
x = [500, 2000, 4000]
values = [17.546, 17.345, 16.835]



# plot
fig, ax = plt.subplots()
ax.plot(x, values)
plt.xlabel('Training iterations')
plt.ylabel('root MSE')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#dfof 1e-04
x = [500, 1000, 2000]
values = [20.793, 21.825, 21.856]

#dfof 1e-04 predict-on-train
x = [500, 1000, 2000]
values = [14.312, 13.159, 11.417]
 
#deconv 1e-04
x = [500, 1000, 2000]
values = [22.572, 22.342, 23.209]

#deconv 1e-04 predict-on-train
x = [500, 1000, 2000]
values = [15.965, 14.998, 14.129]

#dfof 1e-06
x = [500, 1000, 4000]
values = [21.048, 19.598, 20.33]

#dfof 1e-06 predict-on-train
x = [500, 1000, 2000]
values = [15.575,14.236, 14.171]

#deconv 1e-06 
x = [500, 2000, 4000]
values = [23.456, 23.414, 22.977 ]

#deconv 1e-06 predict-on-train
x = [500, 2000, 4000]
values = [17.546, 17.345, 16.835]
